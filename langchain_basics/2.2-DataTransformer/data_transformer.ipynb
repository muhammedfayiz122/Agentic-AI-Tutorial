# %%
from langchain_community.document_loaders.text import TextLoader
loader = TextLoader("src/speech.txt")
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'src/speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.\n\nJust because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\n…\n\nIt will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and fairn
# ...

# %%
# %pip install -qU langchain_community langchain-pymupdf4llm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_pymupdf4llm import PyMuPDF4LLMLoader
pdf_loader = PyMuPDF4LLMLoader("src/syllabus.pdf")
pdf_document = pdf_loader.load()
pdf_document
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-30T20:27:03+00:00', 'source': 'src/syllabus.pdf', 'file_path': 'src/syllabus.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Ultimate Data Science & GenAI Bootcamp', 'author': 'monal singh', 'subject': '', 'keywords': 'DAGdmhcqnYw,BAEmsmap8Lg,0', 'moddate': '2025-01-30T20:26:59+00:00', 'trapped': '', 'modDate': "D:20250130202659+00'00'", 'creationDate': "D:20250130202703+00'00'", 'page': 0}, page_content=''),
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=20)
splitted_document = text_splitter.split_documents(pdf_document)
splitted_document
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-30T20:27:03+00:00', 'source': 'src/syllabus.pdf', 'file_path': 'src/syllabus.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Ultimate Data Science & GenAI Bootcamp', 'author': 'monal singh', 'subject': '', 'keywords': 'DAGdmhcqnYw,BAEmsmap8Lg,0', 'moddate': '2025-01-30T20:26:59+00:00', 'trapped': '', 'modDate': "D:20250130202659+00'00'", 'creationDate': "D:20250130202703+00'00'", 'page': 1}, page_content='This course is designed for aspiring data scientists, machine learning enthusiasts, and\n\nprofessionals looking to build expertise in Python programming, data analysis, machine learning,\n\nand deep learning. Whether you are just starting or have some experience, this comprehensive\n\ncourse will equip you with the skills needed to work with real-world datasets, apply machine\n\nlearning algorithms, and deploy AI solutions. By the end of the course, you’ll have a solid\n\nfoundation in AI,
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(separators="\n\n", chunk_size=1000, chunk_overlap=20)
splitted_document = text_splitter.split_documents(pdf_document)
splitted_document
# Out:
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-01-30T20:27:03+00:00', 'source': 'src/syllabus.pdf', 'file_path': 'src/syllabus.pdf', 'total_pages': 34, 'format': 'PDF 1.4', 'title': 'Ultimate Data Science & GenAI Bootcamp', 'author': 'monal singh', 'subject': '', 'keywords': 'DAGdmhcqnYw,BAEmsmap8Lg,0', 'moddate': '2025-01-30T20:26:59+00:00', 'trapped': '', 'modDate': "D:20250130202659+00'00'", 'creationDate': "D:20250130202703+00'00'", 'page': 1}, page_content='This course is designed for aspiring data scientists, machine learning enthusiasts, and\n\nprofessionals looking to build expertise in Python programming, data analysis, machine learning,\n\nand deep learning. Whether you are just starting or have some experience, this comprehensive\n\ncourse will equip you with the skills needed to work with real-world datasets, apply machine\n\nlearning algorithms, and deploy AI solutions. By the end of the course, you’ll have a solid\n\nfoundation in AI,
# ...
