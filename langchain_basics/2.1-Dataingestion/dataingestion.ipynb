# %%
from langchain_community.document_loaders.text import TextLoader
loader = TextLoader("src/speech.txt")

# %%
text_document = loader.load()
text_document
# Out:
# [Document(metadata={'source': 'src/speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.\n\nJust because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\n…\n\nIt will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and fairn
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ['GITHUB_PERSONAL_ACCESS_TOKEN'] = os.getenv("GITHUB_PERSONAL_ACCESS_TOKEN")

# %%
from langchain_community.document_loaders.github import GithubFileLoader
git_loader = GithubFileLoader(
    repo="muhammedfayiz122/Online-service-market-using-django",
    file_filter=lambda path: path.endswith(('.py', '.md', '.txt', '.html', '.css'))  # Optional filter
    )

# %%
git_document = git_loader.load()

# %%
git_document
# Out:
# [Document(metadata={'path': 'README.md', 'sha': 'c165519edb2a3deec6d27c599d4a918ccbda124c', 'source': 'https://api.github.com/muhammedfayiz122/Online-service-market-using-django/blob/main/README.md'}, page_content='# Online Service Marketplace\n\nA web-based platform built with Django that connects customers with local service providers such as electricians, plumbers, cleaners, and other professionals. The application allows users to browse available services, view worker profiles, and book appointments online.\n\n## Features\n\n- **User Registration & Authentication:** Secure sign-up and login functionality.\n- **Service Provider Listings:** Easily browse, search, and filter local service providers.\n- **Appointment Booking:** Schedule appointments with service providers directly from the platform.\n- **Profile Management:** Service providers can manage their profiles and showcase their skills.\n- **Responsive Design:** Optimized for both desktop and mobile users.\n\n## Technologies
# ...

# %%
from langchain_community.document_loaders import YoutubeLoader
youtube_data = YoutubeLoader(
    video_id="https://youtu.be/vmy3HgaKJsY?si=5q0sv6wJKOrAlhrT",
    add_video_info=True
    )
youtube_data.load()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       1 from langchain_community.document_loaders import YoutubeLoader
#       2 youtube_data = YoutubeLoader(
#       3     video_id="https://youtu.be/vmy3HgaKJsY?si=5q0sv6wJKOrAlhrT",
#       4     add_video_info=True
#       5     )
# ----> 6 youtube_data.load()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\youtube.py:258, in YoutubeLoader.load(self)
#     250     raise ImportError(
#     251         'Could not import "youtube_transcript_api" Python package. '
#     252         "Please install it with `pip install youtube-transcript-api`."
#     253     )
#     255 if self.add_video_info:
#     256     # Get more video meta info
#     257     # Such as title, description, thumbnail url, publish_date
# --> 258     video_info = self._get_video_info()
# ...

# %%
# %pip install --upgrade --quiet  youtube-transcript-api
# %pip install --upgrade --quiet  pytube
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import youtube_transcript_api
import pytube

# %%
loader = YoutubeLoader.from_youtube_url(
    "https://www.youtube.com/watch?v=QsYGlZkevEg",
    add_video_info=True,
    language=["en", "id"],
    translation="en",
)
loader.load()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       1 loader = YoutubeLoader.from_youtube_url(
#       2     "https://www.youtube.com/watch?v=QsYGlZkevEg",
#       3     add_video_info=True,
#       4     language=["en", "id"],
#       5     translation="en",
#       6 )
# ----> 7 loader.load()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_community\document_loaders\youtube.py:258, in YoutubeLoader.load(self)
#     250     raise ImportError(
#     251         'Could not import "youtube_transcript_api" Python package. '
#     252         "Please install it with `pip install youtube-transcript-api`."
#     253     )
#     255 if self.add_video_info:
#     256     # Get more video meta info
#     257     # Such as title, description, thumbnail url, publish_date
# --> 258     video_info = self._get_video_info()
# ...
